# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6), dpi=80)

AB23 = "2-3"
AB24 = "2-4"

# %% [markdown]
# ### Insert 2-3

# %%
in23n = [256, 304, 362, 430, 512, 608, 724, 861, 1024, 1217, 1448, 1722, 2048, 2435, 2896, 3444, 4096, 4870, 5792, 6888, 8192, 9741, 11585, 13777, 16384, 19483, 23170, 27554, 32768, 38967, 46340, 55108]
in23ops =  [0.70703125, 0.7467105263157895, 0.712707182320442, 0.7255813953488373, 0.732421875, 0.7467105263157895, 0.7196132596685083, 0.7131242740998839, 0.7412109375, 0.723911257189811, 0.7306629834254144, 0.7386759581881533, 0.748046875, 0.7523613963039014, 0.7441298342541437, 0.7450638792102207, 0.746826171875, 0.7470225872689938, 0.742921270718232, 0.7423054587688734, 0.733154296875, 0.7417102966841187, 0.7458782908933966, 0.7447194599695144, 0.7486572265625, 0.7432120310013858, 0.7410012947777298, 0.747296218334906, 0.745819091796875, 0.7472989965868555, 0.7490504963314631, 0.7466973942077375]

# %% [markdown]
# ### Insert 2-4

# %%
in24n = [256, 304, 362, 430, 512, 608, 724, 861, 1024, 1217, 1448, 1722, 2048, 2435, 2896, 3444, 4096, 4870, 5792, 6888, 8192, 9741, 11585, 13777, 16384, 19483, 23170, 27554, 32768, 38967, 46340, 55108]
in24ops = [0.5, 0.5032894736842105, 0.505524861878453, 0.5093023255813953, 0.50390625, 0.5230263157894737, 0.5096685082872928, 0.5040650406504065, 0.51953125, 0.5217748562037798, 0.5103591160220995, 0.521486643437863, 0.521484375, 0.5133470225872689, 0.5096685082872928, 0.5133565621370499, 0.517578125, 0.5188911704312115, 0.5153660220994475, 0.5165505226480837, 0.51904296875, 0.5199671491633302, 0.5202416918429003, 0.5189809102126733, 0.51800537109375, 0.5236359903505621, 0.5199827362969357, 0.5168033679320607, 0.520172119140625, 0.5186696435445377, 0.5202848511005611, 0.5190172025840168]

# %% [markdown]
# ### Insert Graph

# %%
# Plotting sequential test
plt.plot(in23n, in23ops, marker='o', color='r', label=AB23)
plt.plot(in24n, in24ops, marker='o', color='c', label=AB24)
plt.title("Insert Test")
plt.xlabel("n")
plt.ylabel("Average structural changes")
plt.legend()

plt.savefig('ABInsertExp.png', bbox_inches='tight')

# %% [markdown]
# ### Min 2-3

# %%
min23n = [256, 304, 362, 430, 512, 608, 724, 861, 1024, 1217, 1448, 1722, 2048, 2435, 2896, 3444, 4096, 4870, 5792, 6888, 8192, 9741, 11585, 13777, 16384, 19483, 23170, 27554, 32768, 38967, 46340, 55108]
min23ops = [4.98828125, 4.987938596491228, 4.321362799263352, 4.989147286821705, 5.66015625, 5.660087719298246, 4.9935543278084715, 5.660859465737515, 6.329752604166667, 6.329772665023281, 5.663213627992634, 6.330042586140147, 6.998046875, 6.998083504449007, 6.331491712707182, 6.998257839721254, 7.665608723958333, 7.665503080082136, 6.999021639042358, 7.665747193186218, 8.332763671875, 8.332717380145775, 7.666148755574738, 8.332849435048752, 8.99969482421875, 8.999674930281099, 8.333045604948929, 8.99973385594348, 9.66650390625, 9.666495581731551, 8.999848942598188, 9.66652754590985]

# %% [markdown]
# ### Min 2-4

# %%
min24n = [256, 304, 362, 430, 512, 608, 724, 861, 1024, 1217, 1448, 1722, 2048, 2435, 2896, 3444, 4096, 4870, 5792, 6888, 8192, 9741, 11585, 13777, 16384, 19483, 23170, 27554, 32768, 38967, 46340, 55108]
min24ops = [0.16145833333333334, 0.1611842105263158, 0.16022099447513813, 0.16279069767441862, 0.16276041666666666, 0.16447368421052633, 0.1643646408839779, 0.16453735965931088, 0.16471354166666666, 0.16488633251164064, 0.1652854511970534, 0.1651180797522261, 0.16552734375, 0.16563997262149213, 0.1658609576427256, 0.16608594657375145, 0.16617838541666666, 0.16611909650924025, 0.16632136279926335, 0.166182733255904, 0.16630045572916666, 0.16630736064059132, 0.16642209753992232, 0.1664610098957199, 0.16646321614583334, 0.16653834967236394, 0.16655157531290463, 0.16655778955263603, 0.16658528645833334, 0.16657684707573076, 0.1665947345705654, 0.1666061793810941]

# %% [markdown]
# ### Min Graph

# %%
# Plotting sequential test
plt.plot(min23n, min23ops, marker='o', color='r', label=AB23)
plt.plot(min24n, min24ops, marker='o', color='c', label=AB24)
plt.title("Min Test")
plt.xlabel("n")
plt.ylabel("Average structural changes")
plt.legend()

plt.savefig('ABMinExp.png', bbox_inches='tight')

# %% [markdown]
# ### Random 2-3

# %%
ran23n = [256, 304, 362, 430, 512, 608, 724, 861, 1024, 1217, 1448, 1722, 2048, 2435, 2896, 3444, 4096, 4870, 5792, 6888, 8192, 9741, 11585, 13777, 16384, 19483, 23170, 27554, 32768, 38967, 46340, 55108]
ran23ops = [0.765625, 0.75, 0.7569060773480663, 0.7976744186046512, 0.7669270833333334, 0.7099780701754386, 0.7306629834254144, 0.7375145180023229, 0.744140625, 0.7296631059983566, 0.7375690607734806, 0.7468060394889663, 0.71728515625, 0.7472963723477071, 0.7505755064456722, 0.7466124661246613, 0.742919921875, 0.7475017111567419, 0.7463743093922652, 0.74312814556717, 0.7454020182291666, 0.7458850905108989, 0.7412170910660336, 0.7371222569015993, 0.7389933268229166, 0.7418262074629164, 0.7455761760897712, 0.7423725532892986, 0.745452880859375, 0.7461612817683339, 0.7441447273773558, 0.7452396506254385]

# %% [markdown]
# ### Random 2-4

# %%
ran24n = [256, 304, 362, 430, 512, 608, 724, 861, 1024, 1217, 1448, 1722, 2048, 2435, 2896, 3444, 4096, 4870, 5792, 6888, 8192, 9741, 11585, 13777, 16384, 19483, 23170, 27554, 32768, 38967, 46340, 55108]
ran24ops = [0.2630208333333333, 0.2807017543859649, 0.28084714548802947, 0.29534883720930233, 0.2994791666666667, 0.2889254385964912, 0.3011049723756906, 0.2969415408439799, 0.3072916666666667, 0.29800054779512464, 0.2992633517495396, 0.302748741773132, 0.2950846354166667, 0.30650239561943876, 0.30029926335174956, 0.3035230352303523, 0.2978515625, 0.30054757015742645, 0.300414364640884, 0.3003774680603949, 0.2992757161458333, 0.3006878143927728, 0.30122284563372176, 0.29679901284749943, 0.2964274088541667, 0.29778097144519156, 0.298820313623939, 0.2981781229585541, 0.2984212239583333, 0.29814971642672006, 0.29831678895123004, 0.29872250852870724]

# %% [markdown]
# ### Random Graph

# %%
# Plotting sequential test
plt.plot(ran23n, ran23ops, marker='o', color='r', label=AB23)
plt.plot(ran24n, ran24ops, marker='o', color='c', label=AB24)
plt.title("Random Test")
plt.xlabel("n")
plt.ylabel("Average structural changes")
plt.legend()

plt.savefig('ABRanExp.png', bbox_inches='tight')
